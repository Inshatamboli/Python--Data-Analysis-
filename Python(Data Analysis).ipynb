# %%
#Subsetting dataset

# %%
import pandas as pd
heart_failure=pd.read_csv('C:/Users/admin/OneDrive/Documents/Desktop/heart_failure dataset.csv')
print(heart_failure)
# Out:
#      Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase  \
# 0             0             0  75.0      No                       582
# 1             1             1  55.0      No                      7861
# 2             2             2  65.0      No                       146
# 3             3             3  50.0     Yes                       111
# 4             4             4  65.0     Yes                       160
# ..          ...           ...   ...     ...                       ...
# 294         294           294  62.0      No                        61
# 295         295           295  55.0      No                      1820
# 296         296           296  45.0      No                      2060
# 297         297           297  45.0      No                      2413
# 298         298           298  50.0      No                       196
#
#     diabetes  ejection_fraction high_blood_pressure  platelets  \
# ...

# %%
#1 Selecting only columns
heart_failure['age']
# Out:
# 0      75.0
# 1      55.0
# 2      65.0
# 3      50.0
# 4      65.0
#        ...
# 294    62.0
# 295    55.0
# 296    45.0
# 297    45.0
# 298    50.0
# Name: age, Length: 299, dtype: float64

# %%
heart_failure[['high_blood_pressure','platelets']].head()
# Out:
#   high_blood_pressure  platelets
# 0                 Yes  265000.00
# 1                  No  263358.03
# 2                  No  162000.00
# 3                  No  210000.00
# 4                  No  327000.00

# %%
heart_failure[['anaemia','diabetes','serum_sodium']].head()
# Out:
#   anaemia diabetes  serum_sodium
# 0      No       No           130
# 1      No       No           136
# 2      No       No           129
# 3     Yes       No           137
# 4     Yes      Yes           116

# %%
#Selecting Rows
heart_failure.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase diabetes  \
# 0           0             0  75.0      No                       582       No
# 1           1             1  55.0      No                      7861       No
# 2           2             2  65.0      No                       146       No
# 3           3             3  50.0     Yes                       111       No
# 4           4             4  65.0     Yes                       160      Yes
#
#    ejection_fraction high_blood_pressure  platelets  serum_creatinine  \
# 0                 20                 Yes  265000.00               1.9
# 1                 38                  No  263358.03               1.1
# 2                 20                  No  162000.00               1.3
# 3                 20                  No  210000.00               1.9
# 4                 20                  No  327000.00               2.7
#
#    serum_sodium     sex smoking  time  DEATH_EVENT
# ...

# %%
heart_failure.tail()
# Out:
#      Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase  \
# 294         294           294  62.0      No                        61
# 295         295           295  55.0      No                      1820
# 296         296           296  45.0      No                      2060
# 297         297           297  45.0      No                      2413
# 298         298           298  50.0      No                       196
#
#     diabetes  ejection_fraction high_blood_pressure  platelets  \
# 294      Yes                 38                 Yes   155000.0
# 295       No                 38                  No   270000.0
# 296      Yes                 60                  No   742000.0
# 297       No                 38                  No   140000.0
# 298       No                 45                  No   395000.0
#
#      serum_creatinine  serum_sodium     sex smoking  time  DEATH_EVENT
# 294               1.1           143    Male     Yes   270            0
# ...

# %%
heart_failure.head(7)
# Out:
#    Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase diabetes  \
# 0           0             0  75.0      No                       582       No
# 1           1             1  55.0      No                      7861       No
# 2           2             2  65.0      No                       146       No
# 3           3             3  50.0     Yes                       111       No
# 4           4             4  65.0     Yes                       160      Yes
# 5           5             5  90.0     Yes                        47       No
# 6           6             6  75.0     Yes                       246       No
#
#    ejection_fraction high_blood_pressure  platelets  serum_creatinine  \
# 0                 20                 Yes  265000.00               1.9
# 1                 38                  No  263358.03               1.1
# 2                 20                  No  162000.00               1.3
# 3                 20                  No  210000.00               1.9
# ...

# %%
heart_failure.tail(7)
# Out:
#      Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase  \
# 292         292           292  52.0      No                       190
# 293         293           293  63.0     Yes                       103
# 294         294           294  62.0      No                        61
# 295         295           295  55.0      No                      1820
# 296         296           296  45.0      No                      2060
# 297         297           297  45.0      No                      2413
# 298         298           298  50.0      No                       196
#
#     diabetes  ejection_fraction high_blood_pressure  platelets  \
# 292      Yes                 38                  No   382000.0
# 293      Yes                 35                  No   179000.0
# 294      Yes                 38                 Yes   155000.0
# 295       No                 38                  No   270000.0
# 296      Yes                 60                  No   742000.0
# ...

# %%
heart_failure.loc[heart_failure['age']<=70]
# Out:
#      Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase  \
# 2             2             2  65.0      No                       146
# 4             4             4  65.0     Yes                       160
# 8             8             8  65.0      No                       157
# 11           11            11  62.0      No                       231
# 18           18            18  70.0     Yes                       125
# ..          ...           ...   ...     ...                       ...
# 281         281           281  70.0      No                       582
# 283         283           283  65.0      No                      1688
# 288         288           288  65.0      No                       892
# 293         293           293  63.0     Yes                       103
# 294         294           294  62.0      No                        61
#
#     diabetes  ejection_fraction high_blood_pressure  platelets  \
# ...

# %%
#Slicing Subsets of Rows
heart_failure[:]
# Out:
#      Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase  \
# 0             0             0  75.0      No                       582
# 2             2             2  65.0      No                       146
# 4             4             4  65.0     Yes                       160
# 5             5             5  90.0     Yes                        47
# 6             6             6  75.0     Yes                       246
# ..          ...           ...   ...     ...                       ...
# 283         283           283  65.0      No                      1688
# 288         288           288  65.0      No                       892
# 289         289           289  90.0     Yes                       337
# 293         293           293  63.0     Yes                       103
# 294         294           294  62.0      No                        61
#
#     diabetes  ejection_fraction high_blood_pressure  platelets  \
# ...

# %%
heart_failure[:5]
# Out:
#    Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase diabetes  \
# 0           0             0  75.0      No                       582       No
# 2           2             2  65.0      No                       146       No
# 4           4             4  65.0     Yes                       160      Yes
# 5           5             5  90.0     Yes                        47       No
# 6           6             6  75.0     Yes                       246       No
#
#    ejection_fraction high_blood_pressure  platelets  serum_creatinine  \
# 0                 20                 Yes   265000.0               1.9
# 2                 20                  No   162000.0               1.3
# 4                 20                  No   327000.0               2.7
# 5                 40                 Yes   204000.0               2.1
# 6                 15                  No   127000.0               1.2
#
#    serum_sodium     sex smoking  time  DEATH_EVENT
# ...

# %%
heart_failure[2:5]
# Out:
#    Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase diabetes  \
# 4           4             4  65.0     Yes                       160      Yes
# 5           5             5  90.0     Yes                        47       No
# 6           6             6  75.0     Yes                       246       No
#
#    ejection_fraction high_blood_pressure  platelets  serum_creatinine  \
# 4                 20                  No   327000.0               2.7
# 5                 40                 Yes   204000.0               2.1
# 6                 15                  No   127000.0               1.2
#
#    serum_sodium     sex smoking  time  DEATH_EVENT
# 4           116  Female      No     8            1
# 5           132    Male     Yes     8            1
# 6           137    Male      No    10            1

# %%
heart_failure[2:]
# Out:
#      Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase  \
# 4             4             4  65.0     Yes                       160
# 5             5             5  90.0     Yes                        47
# 6             6             6  75.0     Yes                       246
# 8             8             8  65.0      No                       157
# 9             9             9  80.0     Yes                       123
# ..          ...           ...   ...     ...                       ...
# 283         283           283  65.0      No                      1688
# 288         288           288  65.0      No                       892
# 289         289           289  90.0     Yes                       337
# 293         293           293  63.0     Yes                       103
# 294         294           294  62.0      No                        61
#
#     diabetes  ejection_fraction high_blood_pressure  platelets  \
# ...

# %%
#Selecting Rows with loc()
heart_failure.iloc[2]
# Out:
# Unnamed: 0                         4
# Unnamed: 0.1                       4
# age                             65.0
# anaemia                          Yes
# creatinine_phosphokinase         160
# diabetes                         Yes
# ejection_fraction                 20
# high_blood_pressure               No
# platelets                   327000.0
# serum_creatinine                 2.7
# serum_sodium                     116
# sex                           Female
# smoking                           No
# time                               8
# DEATH_EVENT                        1
# Name: 4, dtype: object

# %%
heart_failure.loc[4]
# Out:
# Unnamed: 0                         4
# Unnamed: 0.1                       4
# age                             65.0
# anaemia                          Yes
# creatinine_phosphokinase         160
# diabetes                         Yes
# ejection_fraction                 20
# high_blood_pressure               No
# platelets                   327000.0
# serum_creatinine                 2.7
# serum_sodium                     116
# sex                           Female
# smoking                           No
# time                               8
# DEATH_EVENT                        1
# Name: 4, dtype: object

# %%
heart_failure.iloc[1]
# Out:
# Unnamed: 0                         2
# Unnamed: 0.1                       2
# age                             65.0
# anaemia                           No
# creatinine_phosphokinase         146
# diabetes                          No
# ejection_fraction                 20
# high_blood_pressure               No
# platelets                   162000.0
# serum_creatinine                 1.3
# serum_sodium                     129
# sex                             Male
# smoking                          Yes
# time                               7
# DEATH_EVENT                        1
# Name: 2, dtype: object

# %%
heart_failure.iloc[[1,5,7]]
# Out:
#     Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase diabetes  \
# 2            2             2  65.0      No                       146       No
# 8            8             8  65.0      No                       157       No
# 10          10            10  75.0     Yes                        81       No
#
#     ejection_fraction high_blood_pressure  platelets  serum_creatinine  \
# 2                  20                  No  162000.00               1.3
# 8                  65                  No  263358.03               1.5
# 10                 38                 Yes  368000.00               4.0
#
#     serum_sodium     sex smoking  time  DEATH_EVENT
# 2            129    Male     Yes     7            1
# 8            138  Female      No    10            1
# 10           131    Male     Yes    10            1

# %%
heart_failure.iloc[1:7,:]
# Out:
#    Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase diabetes  \
# 2           2             2  65.0      No                       146       No
# 4           4             4  65.0     Yes                       160      Yes
# 5           5             5  90.0     Yes                        47       No
# 6           6             6  75.0     Yes                       246       No
# 8           8             8  65.0      No                       157       No
# 9           9             9  80.0     Yes                       123       No
#
#    ejection_fraction high_blood_pressure  platelets  serum_creatinine  \
# 2                 20                  No  162000.00               1.3
# 4                 20                  No  327000.00               2.7
# 5                 40                 Yes  204000.00               2.1
# 6                 15                  No  127000.00               1.2
# 8                 65                  No  263358.03               1.5
# ...

# %%
heart_failure.loc[1:7,['age','anaemia']]
# Out:
#     age anaemia
# 2  65.0      No
# 4  65.0     Yes
# 5  90.0     Yes
# 6  75.0     Yes

# %%
heart_failure.iloc[[2,3,6],[3,5]]
# Out:
#   anaemia diabetes
# 4     Yes      Yes
# 5     Yes       No
# 9     Yes       No

# %%
import pandas as pd
heart_failure=pd.read_csv('C:/Users/admin/OneDrive/Documents/Desktop/heart_failure dataset.csv')
print(heart_failure)
# Out:
#      Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase  \
# 0             0             0  75.0      No                       582
# 1             1             1  55.0      No                      7861
# 2             2             2  65.0      No                       146
# 3             3             3  50.0     Yes                       111
# 4             4             4  65.0     Yes                       160
# ..          ...           ...   ...     ...                       ...
# 294         294           294  62.0      No                        61
# 295         295           295  55.0      No                      1820
# 296         296           296  45.0      No                      2060
# 297         297           297  45.0      No                      2413
# 298         298           298  50.0      No                       196
#
#     diabetes  ejection_fraction high_blood_pressure  platelets  \
# ...

# %%
heart_failure[heart_failure['serum_creatinine'] == 1.9 ]
# Out:
#     Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase diabetes  \
# 0            0             0  75.0      No                       582       No
# 3            3             3  50.0     Yes                       111       No
# 19          19            19  48.0     Yes                       582      Yes
# 25          25            25  80.0      No                       148      Yes
# 45          45            45  50.0      No                       582      Yes
#
#     ejection_fraction high_blood_pressure  platelets  serum_creatinine  \
# 0                  20                 Yes   265000.0               1.9
# 3                  20                  No   210000.0               1.9
# 19                 55                  No    87000.0               1.9
# 25                 38                  No   149000.0               1.9
# 45                 38                  No   310000.0               1.9
#
#     serum_sodium     sex smoking  time  DEATH_EVENT
# ...

# %%
heart_failure[heart_failure['serum_creatinine'] != 1.9 ]
# Out:
#      Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase  \
# 1             1             1  55.0      No                      7861
# 2             2             2  65.0      No                       146
# 4             4             4  65.0     Yes                       160
# 5             5             5  90.0     Yes                        47
# 6             6             6  75.0     Yes                       246
# ..          ...           ...   ...     ...                       ...
# 294         294           294  62.0      No                        61
# 295         295           295  55.0      No                      1820
# 296         296           296  45.0      No                      2060
# 297         297           297  45.0      No                      2413
# 298         298           298  50.0      No                       196
#
#     diabetes  ejection_fraction high_blood_pressure  platelets  \
# ...

# %%
heart_failure[heart_failure['serum_creatinine'] > 1.9 ]
# Out:
#      Unnamed: 0  Unnamed: 0.1   age anaemia  creatinine_phosphokinase  \
# 4             4             4  65.0     Yes                       160
# 5             5             5  90.0     Yes                        47
# 9             9             9  80.0     Yes                       123
# 10           10            10  75.0     Yes                        81
# 28           28            28  58.0     Yes                        60
# 31           31            31  85.0      No                        23
# 35           35            35  69.0      No                       582
# 38           38            38  60.0      No                      2656
# 39           39            39  60.0      No                       235
# 48           48            48  80.0     Yes                       553
# 52           52            52  60.0      No                      3964
# 54           54            54  60.0     Yes                       260
# ...

# %%
pd.isnull(heart_failure)
# Out:
#      Unnamed: 0  Unnamed: 0.1    age  anaemia  creatinine_phosphokinase  \
# 0         False         False  False    False                     False
# 1         False         False  False    False                     False
# 2         False         False  False    False                     False
# 3         False         False  False    False                     False
# 4         False         False  False    False                     False
# ..          ...           ...    ...      ...                       ...
# 294       False         False  False    False                     False
# 295       False         False  False    False                     False
# 296       False         False  False    False                     False
# 297       False         False  False    False                     False
# 298       False         False  False    False                     False
#
#      diabetes  ejection_fraction  high_blood_pressure  platelets  \
# ...
